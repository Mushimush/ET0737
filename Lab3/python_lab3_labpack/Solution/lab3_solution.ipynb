# %% [markdown]
# # Lab 3: Functions, Modules and OOP (Solution)
#
# This notebook demonstrates the working solution.

# %% [markdown]
# ## Part 1: Function in student.py

# %%
import time
import student

current_ts = int(time.time())
print('Current Unix timestamp:', current_ts)
print('Readable date:', student.unixtime_date(current_ts))

# %% [markdown]
# ## Part 2: OOP with Parent and Child Classes

# %%
from JsonFile import JsonFile
from CsvFile import CsvFile
from LogFile import LogFile

json_handler = JsonFile('sample.json')
csv_handler = CsvFile('sample.csv')
log_handler = LogFile('sample.log')

print('JSON size:', json_handler.filesize())
print('JSON read:', json_handler.read())
print()
print('CSV size:', csv_handler.filesize())
print('CSV read:', csv_handler.read())
print()
print('LOG size:', log_handler.filesize())
print('LOG read:', log_handler.read())

# %% [markdown]
# ## Part 3: Command Line Test

# %%
# Run these in terminal, not inside the notebook:
# python3 FileHandler.py sample.json
# python3 FileHandler.py sample.csv
# python3 FileHandler.py sample.log

# %% [markdown]
# ## Expected Regex Pattern for LogFile
# `^\\d{4}-\\d{2}-\\d{2} \\d{2}:\\d{2}:\\d{2} \\[Error\\] .+$`
